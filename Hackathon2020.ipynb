# %%
import sys
sys.path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xlrd

# %%
questionBank = '/Users/Alexandra/Documents/HackathonQuestionBank.xlsx'
questions = pd.read_excel(questionBank, sheet_name= 0
)

# %%
questions.head()
# Out:
#                                             Question  \
# 0  What is the minimum number of infectious virus...
# 1   What is not a way that diseases are transmitted?
# 2                  What disease has been eradicated?
# 3           Can a virus be treated with antibiotics?
# 4                                  What is a fomite?
#
#                                   Correct Answer  \
# 0                                              3
# 1                                    eye-contact
# 2                                       smallpox
# 3                                             No
# 4  An object likely to carry infectious material
#
#                                             Choice 1      Choice 2  \
# 0                                                 20             9
# 1                                            droplet       aerosol
# 2                                            anthrax  tuberculosis
# 3                                                Yes     Sometimes
# 4  {A state of the art mask, An eradicated diseas...           NaN
#
#         Choice 3 Difficulty  Answered   \
# 0            100       Hard      False
# 1     fecal-oral       Easy      False
# 2  heart disease       Easy      False
# 3   Only the flu       Easy      False
# 4            NaN       Hard      False
#
#                                               Source  Picture   COVID
# 0  New England Journal of Medicine, https://www.n...      0.0  False
# 1                                                NaN      0.0  False
# 2                                                NaN      NaN  False
# 3                                                NaN      NaN  False
# 4                                                NaN      NaN  False

# %%
questions.shape
# Out:
# (41, 10)

# %%
questions.rename(columns={"COVID": "COVID Related"} ,inplace=True )

# %%
questions.drop(["Picture", "Source"], axis=1)
# Out:
#                                              Question  \
# 0   What is the minimum number of infectious virus...
# 1    What is not a way that diseases are transmitted?
# 2                   What disease has been eradicated?
# 3            Can a virus be treated with antibiotics?
# 4                                   What is a fomite?
# 5   What city is it believed that the COVID-19 out...
# 6                              What is a coronavirus?
# 7                  COVID-19 is a type of coronavirus?
# 8           COVID-19 is the only type of coronavirus?
# 9                What is another type of coronavirus?
# 10   What country did the COVID-19 pandemic begin in?
# 11           How long should you wash your hands for?
# 12  How many times should you sing Happy Birthday ...
# 13            What's the best way to wash your hands?
# 14  Which virus or disease was not discovered duri...
# 15                             What is herd immunity?
# 16  What is the minimum percent of the population ...
# 17  Which disease does not have an effective vaccine?
# 18  What is the scientific name of the virus that ...
# 19      Where does the name "corona"-virus come from?
# 20  What common drug has been shown to reduced mor...
# 21  What non-invasive practice reduces the chance ...
# 22              How many coronaviruses infect humans?
# 23        Which coronavirus is most deadly in humans?
# 24  What country did the 2012 MERS outbreak begin in?
# 25  What country first reported cases of MERS in 2012
# 26  What animal is suspected to be a resevoir host...
# 27                                  Is a virus alive?
# 28  Drinking lots of orange juice can help prevent...
# 29  Why does wearing a mask help prevent the sprea...
# 30  A mask is effective when it covers just your m...
# 31  Only medical grade masks are effective. Cloth ...
# 32  Who should carry garlic to prevent the coronav...
# 33  How many strains of COVID-19 have been identif...
# 34       What is a possible complication of COVID-19?
# 35  What is the most variable part of the coronavi...
# 36  What biosafety level must scientists studying ...
# 37  Can COVID-19 be transmitted through a blood tr...
# 38  Scientists have confirmed that COVID-19 can be...
# 39  Someone can become infected with COVID-19 by t...
# 40                    How many viruses affect humans?
#
#                                        Correct Answer  \
# 0                                                   3
# 1                                         eye-contact
# 2                                            smallpox
# 3                                                  No
# 4       An object likely to carry infectious material
# 5                                               Wuhan
# 6   A virus that causes an infection in your nose,...
# 7                                                True
# 8                                               False
# 9                                                MERS
# 10                                              China
# 11                                         20 seconds
# 12                                              Twice
# 13  By using soap and water, because the soap help...
# 14                                       Tuberculosis
# 15  When most of the population is immune to an in...
# 16                                                0.8
# 17                                       Tuberculosis
# 18                                         SARS-CoV-2
# 19  Under a microscope the virus has a halo called...
# 20                                      Dexamethasone
# 21      Proning (placing patients on their stomaches)
# 22                                                  7
# 23                                               MERS
# 24                                             Jordan
# 25                                       Saudi Arabia
# 26                                             Camels
# 27                                                 No
# 28                                              False
# 29  It prevents you from exhaling nfected droplets...
# 30                                              False
# 31                                              False
# 32                                            No one.
# 33                                                  2
# 34  Cytokine storm, or an uncontrolled inflamatry ...
# 35  The Receptor Binding Domain (RBD) in the spike...
# 36                                            Level 2
# 37  It is unlikely but scientists do not yet have ...
# 38                                               True
# 39                                               True
# 40                                           Over 200
#
#                                              Choice 1  \
# 0                                                  20
# 1                                             droplet
# 2                                             anthrax
# 3                                                 Yes
# 4   {A state of the art mask, An eradicated diseas...
# 5                                               Seoul
# 6                                    A skin infection
# 7                                              False
# 8                                               True
# 9                                                  TB
# 10                                      United States
# 11                                         5 minutes
# 12                                           8 times
# 13                  Just water. Soap isn't necessary.
# 14                                              Ebola
# 15  When the people who are sick from an infectiou...
# 16                                               0.25
# 17                                              Polio
# 18                                                HIV
# 19  The scientist who discovered the first coronav...
# 20                                 Hydroxychloroquine
# 21                                          IV Fluids
# 22                                                  3
# 23                                               SARS
# 24                                       Saudi Arabia
# 25                                             Jordan
# 26                                               Bats
# 27                                                Yes
# 28                                              True
# 29  It makes you look unfriendly so people are les...
# 30                                              True
# 31                                              True
# 32                                           Vampires
# 33                                                  5
# 34                                  T-cell mutilation
# 35                                   The virus shape
# 36                                            Level 1
# 37                                                Yes
# 38                                             False
# 39                                             False
# 40                                      Less than 100
#
#                                              Choice 2  \
# 0                                                   9
# 1                                             aerosol
# 2                                        tuberculosis
# 3                                           Sometimes
# 4                                                 NaN
# 5                                              London
# 6                               A type of broken bone
# 7                                                 NaN
# 8                                                 NaN
# 9                                                COPD
# 10                                          Argentina
# 11                                        45 seconds
# 12                                               Once
# 13  With no soap and only cold water to kill any b...
# 14                                                HIV
# 15  High Estimate of Residual Disease (HERD) Immunity
# 16                                            0.99999
# 17                                         Chickenpox
# 18                                           MERS-CoV
# 19  The coronavirus family has the the "kings" of ...
# 20                                        Amoxicillin
# 21                                   Nicotine Patches
# 22                                                  1
# 23                                           COVID-19
# 24                                              China
# 25                                              China
# 26                                            Ferrets
# 27                                    Only in a host.
# 28                                                NaN
# 29  It doesn't. People who think it does are delus...
# 30                                                NaN
# 31                                                NaN
# 32  People in crowded areas. The garlic smell will...
# 33                                                  1
# 34                               Bone marrow collapse
# 35                The Nuclear Capsule Structure (NCS)
# 36                                            Level 3
# 37                                                 No
# 38                                                NaN
# 39                                                NaN
# 40                                      Only COVID-19
#
#                                              Choice 3 Difficulty  Answered   \
# 0                                                 100       Hard      False
# 1                                          fecal-oral       Easy      False
# 2                                       heart disease       Easy      False
# 3                                        Only the flu       Easy      False
# 4                                                 NaN       Hard      False
# 5                                       New York City       Easy      False
# 6                                 A bacterial disease       Easy      False
# 7                                                 NaN       Easy      False
# 8                                                 NaN       Hard      False
# 9                                                 HIV       Hard      False
# 10                                            Somalia       Easy      False
# 11                                          5 seconds       Easy      False
# 12                                  It doesn't matter       Easy      False
# 13  It doesn't matter. Water by itself s just as g...       Easy      False
# 14                                               SARS       Hard      False
# 15  When doctors form groups, called "herds," to i...       Easy      False
# 16                                                0.5       Hard      False
# 17                                            Measles       Hard      False
# 18                                           COVID-19       Hard      False
# 19  Corona was the name of the city in which the f...       Easy      False
# 20                                             Aviane       Hard      False
# 21                                        Intubations       Hard      False
# 22                                                 10       Hard      False
# 23                                              Ebola       Hard      False
# 24                                             France       Hard      False
# 25                                      United States       Hard      False
# 26                                          Armadillo       Easy      False
# 27                           It depends on the virus.       Easy      False
# 28                                                NaN       easy      False
# 29  It only helps when someone is symptomatic (cou...       Easy      False
# 30                                                NaN       Easy      False
# 31                                                NaN       Easy      False
# 32                                            Doctors       Easy      False
# 33                                                  3       Hard      False
# 34                                       Vein atrophy       Hard      False
# 35                 Membrane Elasticity Quotient (MEQ)     Expert      False
# 36                                            Level 4     Expert      False
# 37           Only if the person is highly infectious.     Expert      False
# 38                                                NaN       Easy      False
# 39                                                NaN       Easy      False
# 40                   Too many to accurately identify.       Easy      False
#
#    COVID Related
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5           True
# 6           True
# 7           True
# 8           True
# 9           True
# 10          True
# 11          True
# 12           NaN
# 13           NaN
# 14        False
# 15        False
# 16        False
# 17        False
# 18          True
# 19          True
# 20          True
# 21          True
# 22          True
# 23          True
# 24          True
# 25          True
# 26          True
# 27        False
# 28          True
# 29          True
# 30          True
# 31          True
# 32          True
# 33          True
# 34          True
# 35          True
# 36          True
# 37          True
# 38          True
# 39          True
# 40        False

# %%
questions.to_json(r'./QuestionBank.json', orient= 'records')
