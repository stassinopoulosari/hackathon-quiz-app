# %%
import sys
sys.path
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import xlrd

# %%
questionBank = '/Users/Alexandra/Documents/HackathonQuestionBank.xlsx'
questions = pd.read_excel(questionBank, sheet_name= 0
)

# %%
questions.head()
# Out:
#                                             Question  \
# 0  How many infectious virus particles can make s...
# 1   What is not a way that diseases are transmitted?
# 2                  What disease has been eradicated?
# 3           Can a virus be treated with antibiotics?
# 4                                  What is a fomite?
#
#                                       Correct Answer                 Choice 1  \
# 0                                                  3                       20
# 1                                        eye-contact                  droplet
# 2                                           smallpox                  anthrax
# 3                                                 No                      Yes
# 4  An object that can spread an infectious diseas...  A state of the art mask
#
#                  Choice 2                      Choice 3 Difficulty  Answered   \
# 0                       9                           100       Hard      False
# 1                 aerosol                    fecal-oral       Easy      False
# 2            tuberculosis                 heart disease       Easy      False
# 3               Sometimes                  Only the flu       Easy      False
# 4   An eradicated disease  Something used at a hospital     Expert      False
#
#                                               Source  Picture   COVID
# 0  New England Journal of Medicine, https://www.n...      0.0  False
# 1                                                NaN      0.0  False
# 2                                                NaN      NaN  False
# 3                                                NaN      NaN  False
# 4                                                NaN      NaN  False

# %%
questions.shape
# Out:
# (40, 10)

# %%
questions.rename(columns={"COVID": "COVID Related"} ,inplace=True )

# %%
questions.drop(["Picture", "Source"], axis=1, inplace=True)
questions.head()
# Out:
#                                             Question  \
# 0  How many infectious virus particles can make s...
# 1   What is not a way that diseases are transmitted?
# 2                  What disease has been eradicated?
# 3           Can a virus be treated with antibiotics?
# 4                                  What is a fomite?
#
#                                       Correct Answer                 Choice 1  \
# 0                                                  3                       20
# 1                                        eye-contact                  droplet
# 2                                           smallpox                  anthrax
# 3                                                 No                      Yes
# 4  An object that can spread an infectious diseas...  A state of the art mask
#
#                  Choice 2                      Choice 3 Difficulty  Answered   \
# 0                       9                           100       Hard      False
# 1                 aerosol                    fecal-oral       Easy      False
# 2            tuberculosis                 heart disease       Easy      False
# 3               Sometimes                  Only the flu       Easy      False
# 4   An eradicated disease  Something used at a hospital     Expert      False
#
#   COVID Related
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
questions.to_json(r'./QuestionBank.json', orient= 'records')
